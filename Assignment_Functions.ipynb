# %% [markdown]
# ### Functions (Theoritical)

# %% [markdown]
# Q1  What is the difference between a function and a method in Python
#
#   Ans-> Organized program statements that perform a specific and relevant task and can be used again and again in the program is called Python’s function.
#
#   def add(x,y) is a function
#
#   While A ‘method’ is a function that is associated with a class or an object. The’ method’ is always dependent on the class to which it is associated.

# %% [markdown]
# Q2  Explain the concept of function arguments and parameters in Python.
#
#   Ans-> A parameter is a variable named in the function or method definition. It acts as a placeholder for the data the function will use.
#
#   while  argument is the actual value that is passed to the function or method when it is called.
#
#   def add(x,y)
#
#   here x and y are parameters but..
#
#   add(5,8)
#
#   when we are acually using the add function, 5 & 8 becomes argument

# %% [markdown]
# Q3 What are the different ways to define and call a function in Python
#
#   Ans-> To define a function we use a keyword def to declare the function, followed by the function name and parentheses brackets. For example, def greet(name):.
#
#    To call the function, type its name followed by any required parameters in parentheses. For example, greet("Rahul").

# %% [markdown]
# Q4  What is the purpose of the `return` statement in a Python function?
#
#   Ans-> The return statement in python is a special statement that we use inside a function to send the function's result back to the caller. A return statement consists of the return keyword followed by an optional return value.
#
#   def name(x):
#
#   return(x)
#
#   >>
#   name(Rahul)
#
#   Rahul

# %% [markdown]
# Q5  What are iterators in Python and how do they differ from iterables?
#
#   Ans-> Iterators are methods that iterate collections. Using an iterator method, we can loop through an object and return its elements.
#
#   while iterables are objects which can be iterated
#   for example lists tuples etc

# %% [markdown]
# Q6  Explain the concept of generators in Python and how they are defined.
#
#   Ans-> A generator is a type of function that returns an iterator object. Instead of using return to send back a single value, generator functions use yield to produce result one at a time. This allows the function to generate values and pause its execution after each yield.
#
#   They are defined simillar to a function but without a return keyword rather having yield in its place
#
#   def generator_name(arg):
#
#   statements
#
#   yield something

# %% [markdown]
# Q7 . What are the advantages of using generators over regular functions?
#
#   Ans-> For a very high number of iterables there is a possiblity of using a large memory in python. This slows down the process. Hence Generators are useful when we want to produce a large sequence of values, but we don't want to store all of them in memory at once and give each answer one at a time.
#
#   def square (n)
#
#   for i in range(n)
#
#   a=i**2
#   yeild a
#
#   if n= 10000 then it will take a lot of memory if all is run at once. Therefore generator is required

# %% [markdown]
# Q8 What is a lambda function in Python and when is it typically used?
#
#   Ans-> A lambda function is a special type of function without the function name, anonymous function. lambda argument(s) : expression
#
#   it is shorter form of defining a function that helps in programming
#
#    declare a lambda function
#    greet = lambda : print('Hello World')
#
#
#    greet()
#    Output: Hello World

# %% [markdown]
# Q9  Explain the purpose and usage of the `map()` function in Python.
#
#   Ans -> The map() function is used to apply a given function to every item of an iterable
#   It helps in reducing the complexity of language.
#
#   map(function, iterable)
#
#   s = ['1', '2', '3', '4']
#
#   res = map(int, s)
#
#   print(list(res))
#
#   Map is helping to convert all the string into integer with one comand.

# %% [markdown]
# Q10  What is the difference between `map()`, `reduce()`, and `filter()` functions in Python
#
#   Ans-> The map() function iterates through all items in the given iterable and executes the function we passed as an argument on each of them.
#
#   filter() forms a new list that contains only elements that satisfy a certain condition, i.e. the function we passed returns True
#
#   reduce() works by calling the function we passed for the first two items in the sequence. The result returned by the function is used in another call to function alongside with the next (third in this case), element. This process repeats until we've gone through all the elements in the sequence.

# %% [markdown]
# Q11   Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
#
#   Ans-> First we write a function to add
#
#   def add(x,y)
#
#   return(x+y)
#
#   now reduce
#
#   reduce(add,list)
#
#   The mechanism is attached in the picture within

# %% [markdown]
# ![WhatsApp Image 2025-01-14 at 12.44.34_6acb55b5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Practical Questions

# %%
# Q1  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list



def add (*x):
  sum=0

  for i in x:
    if i%2==0:
      sum=sum+i
  return(sum)


add(2,6,9,13,10)
# Out:
# 18

# %%
# Q2 . Create a Python function that accepts a string and returns the reverse of that string.

str1=input("Please enter a string : ")

def reversestring(str1):
  return str1[::-1]

reversestring(str1)
# Out:
# Please enter a string : Hi my name is Fariz
# 'ziraF si eman ym iH'

# %%
# Q3 Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

def square(*a):
  n=[]
  for i in a:
    n.append(i**2)
  return n

square(2,3,4,5,6)
# Out:
# [4, 9, 16, 25, 36]

# %%
# Q4 Write a Python function that checks if a given number is prime or not from 1 to 200.

def prime(x):
  if x==0 or x==1:
    return("not a prime number")
  for i in range(2,x):
    if x%i==0:
      return(x,"Not a prime number")
      break
  else:
    ("Is a prime number")

print(prime(21))
# Out:
# (21, 'Not a prime number')

# %%
# Q5 Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

def fi (n):
  a=0
  b=1
  for i in range(0,n+1):
    n=[]
    yield a
    a=b
    b=a+b


z=fi(5)

# %%
next(z)
# Out:
# 0

# %%
next(z)
# Out:
# 1

# %%
# Q6 Write a generator function in Python that yields the powers of 2 up to a given exponent.

def square(n):
  for i in range(n):
    yield i**2

ren= square(4)
next(ren)
# Out:
# 0

# %%
next(ren)
# Out:
# 1

# %%
next(ren)
# Out:
# 4

# %%
next(ren)
# Out:
# 9

# %%
# Q7  Implement a generator function that reads a file line by line and yields each line as a string

## not taught in class#

# %%
# Q8 Use a lambda function in Python to sort a list of tuples based on the second element of each tuple
list2=[(2,4,5),(4,1,7),(9,2,0)]
list2.sort(key=lambda x:x[1])
print(list2)
# Out:
# [(4, 1, 7), (9, 2, 0), (2, 4, 5)]

# %%
# Q9 Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit

list3=[23,56,78]
def convert (x):
  y=((x*9)/5) + 32
  return y

list(map(convert,list3))
# Out:
# [73.4, 132.8, 172.4]

# %%
# Q10 . Create a Python program that uses `filter()` to remove all the vowels from a given string.


str5="hello dear"
def vowelremove (x):
  a=["a","A","e","E","i","I","o","O","u","U"]
  for i in x:
    if i in a:
      return False
    else:
      return True


filtered_letters=list(filter(vowelremove,str5))
print(filtered_letters)
# Out:
# ['h', 'l', 'l', ' ', 'd', 'r']

# %%
# Q11  Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:

order=[34587,98762,77226,88112]
quantity=[4,5,3,3]
price=[40.95,56.80,32.95,24.99]
#Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity.
#The product should be increased by 10,- € if the value of the order is smaller than 100,00 €.
#Write a Python program using lambda and map.

list10=list(map(lambda x,y: x*y if x*y>100 else (x*y)+10,quantity,price))
list10
# Out:
# [163.8, 284.0, 108.85000000000001, 84.97]

# %%
Final_list=list(zip(order,list10))
Final_list
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
